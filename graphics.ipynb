# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("metricas.csv")
df
# Out:
#      procesos   t_max_s   t_min_s   t_avg_s
# 0           2  4.695522  4.560618  4.628070
# 1           2  4.683911  4.553398  4.618654
# 2           2  5.183715  4.727424  4.955570
# 3           2  4.984912  4.653094  4.819003
# 4           2  4.692979  4.614986  4.653982
# ..        ...       ...       ...       ...
# 795         9  1.709638  1.019287  1.186798
# 796         9  1.712996  1.019847  1.185772
# 797         9  1.712616  1.015011  1.186461
# 798         9  1.710345  1.015042  1.184724
# 799         9  1.712341  1.010187  1.183332
#
# [800 rows x 4 columns]

# %%
df.groupby("procesos")["t_avg_s"].std().plot(kind="bar")
# Out:
# <Axes: xlabel='procesos'>

# %%
sns.boxplot(data=df, x='procesos', y='t_avg_s')
plt.show()
