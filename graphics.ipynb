# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("metricas.csv")
df
# Out:
#      corrida  procesos  iteraciones   t_max_s   t_min_s   t_avg_s
# 0          1         2        10000  2.128215  2.114513  2.121364
# 1          2         2        10000  2.111873  2.111821  2.111847
# 2          3         2        10000  2.112525  2.107256  2.109890
# 3          4         2        10000  2.118292  2.107921  2.113106
# 4          5         2        10000  2.111526  2.102185  2.106856
# ..       ...       ...          ...       ...       ...       ...
# 305        6        32        10000  0.447811  0.429628  0.436802
# 306        7        32        10000  0.443731  0.432249  0.438348
# 307        8        32        10000  0.445777  0.432288  0.438713
# 308        9        32        10000  0.443266  0.432767  0.438302
# 309       10        32        10000  0.443050  0.432819  0.438068
#
# [310 rows x 6 columns]

# %%
df.groupby("procesos")["t_avg_s"].std().plot(kind="bar")
# Out:
# <Axes: xlabel='procesos'>

# %%
sns.boxplot(data=df, x='procesos', y='t_avg_s')
plt.show()
